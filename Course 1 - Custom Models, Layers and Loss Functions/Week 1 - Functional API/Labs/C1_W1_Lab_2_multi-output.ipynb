# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split
# Out:
# WARNING:tensorflow:From c:\Users\Imokut\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)


# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()


# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()

train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# WARNING:tensorflow:From c:\Users\Imokut\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 8)]                  0         []
#
#  dense (Dense)               (None, 128)                  1152      ['input_1[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  16512     ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 64)                   8256      ['dense_1[0][0]']
#
#  y1_output (Dense)           (None, 1)                    129       ['dense_1[0][0]']
#
#  y2_output (Dense)           (None, 1)                    65        ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 26114 (102.01 KB)
# Trainable params: 26114 (102.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Epoch 1/500
# WARNING:tensorflow:From c:\Users\Imokut\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# WARNING:tensorflow:From c:\Users\Imokut\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# WARNING:tensorflow:From c:\Users\Imokut\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# WARNING:tensorflow:From c:\Users\Imokut\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# 62/62 [==============================] - 9s 36ms/step - loss: 234.3125 - y1_output_loss: 108.4856 - y2_output_loss: 125.8269 - y1_output_root_mean_squared_error: 10.4156 - y2_output_root_mean_squared_error: 11.2173 - val_loss: 46.6990 - val_y1_output_loss: 17.2688 - val_y2_output_loss: 29.4302 - val_y1_output_root_mean_squared_error: 4.1556 - val_y2_output_root_mean_squared_error: 5.4250
# Epoch 2/500
# 62/62 [==============================] - 1s 12ms/step - loss: 32.4639 - y1_output_loss: 12.3334 - y2_output_loss: 20.1305 - y1_output_root_mean_squared_error: 3.5119 - y2_output_root_mean_squared_error: 4.4867 - val_loss: 62.2451 - val_y1_output_loss: 17.3837 - val_y2_output_loss: 44.8615 - val_y1_output_root_mean_squared_error: 4.1694 - val_y2_output_root_mean_squared_error: 6.6979
# Epoch 3/500
# 62/62 [==============================] - 1s 9ms/step - loss: 24.8571 - y1_output_loss: 9.7739 - y2_output_loss: 15.0833 - y1_output_root_mean_squared_error: 3.1263 - y2_output_root_mean_squared_error: 3.8837 - val_loss: 23.8392 - val_y1_output_loss: 10.6979 - val_y2_output_loss: 13.1412 - val_y1_output_root_mean_squared_error: 3.2708 - val_y2_output_root_mean_squared_error: 3.6251
# Epoch 4/500
# 62/62 [==============================] - 1s 10ms/step - loss: 26.3727 - y1_output_loss: 9.8799 - y2_output_loss: 16.4929 - y1_output_root_mean_squared_error: 3.1432 - y2_output_root_mean_squared_error: 4.0611 - val_loss: 20.9739 - val_y1_output_loss: 10.1060 - val_y2_output_loss: 10.8679 - val_y1_output_root_mean_squared_error: 3.1790 - val_y2_output_root_mean_squared_error: 3.2966
# Epoch 5/500
# 62/62 [==============================] - 1s 8ms/step - loss: 23.2412 - y1_output_loss: 8.9049 - y2_output_loss: 14.3363 - y1_output_root_mean_squared_error: 2.9841 - y2_output_root_mean_squared_error: 3.7863 - val_loss: 192.5903 - val_y1_output_loss: 32.5277 - val_y2_output_loss: 160.0625 - val_y1_output_root_mean_squared_error: 5.7033 - val_y2_output_root_mean_squared_error: 12.6516
# Epoch 6/500
# 62/62 [==============================] - 1s 10ms/step - loss: 24.8706 - y1_output_loss: 8.8266 - y2_output_loss: 16.0440 - y1_output_root_mean_squared_error: 2.9710 - y2_output_root_mean_squared_error: 4.0055 - val_loss: 24.6756 - val_y1_output_loss: 8.8267 - val_y2_output_loss: 15.8490 - val_y1_output_root_mean_squared_error: 2.9710 - val_y2_output_root_mean_squared_error: 3.9811
# Epoch 7/500
# 62/62 [==============================] - 0s 6ms/step - loss: 25.6950 - y1_output_loss: 9.3203 - y2_output_loss: 16.3747 - y1_output_root_mean_squared_error: 3.0529 - y2_output_root_mean_squared_error: 4.0466 - val_loss: 38.7998 - val_y1_output_loss: 12.6271 - val_y2_output_loss: 26.1728 - val_y1_output_root_mean_squared_error: 3.5535 - val_y2_output_root_mean_squared_error: 5.1159
# Epoch 8/500
# 62/62 [==============================] - 0s 8ms/step - loss: 21.0173 - y1_output_loss: 8.3696 - y2_output_loss: 12.6477 - y1_output_root_mean_squared_error: 2.8930 - y2_output_root_mean_squared_error: 3.5564 - val_loss: 47.8671 - val_y1_output_loss: 14.0071 - val_y2_output_loss: 33.8601 - val_y1_output_root_mean_squared_error: 3.7426 - val_y2_output_root_mean_squared_error: 5.8189
# Epoch 9/500
# 62/62 [==============================] - 1s 11ms/step - loss: 23.1705 - y1_output_loss: 8.7068 - y2_output_loss: 14.4637 - y1_output_root_mean_squared_error: 2.9507 - y2_output_root_mean_squared_error: 3.8031 - val_loss: 17.1524 - val_y1_output_loss: 8.4793 - val_y2_output_loss: 8.6732 - val_y1_output_root_mean_squared_error: 2.9119 - val_y2_output_root_mean_squared_error: 2.9450
# Epoch 10/500
# 62/62 [==============================] - 1s 14ms/step - loss: 19.8244 - y1_output_loss: 8.0234 - y2_output_loss: 11.8010 - y1_output_root_mean_squared_error: 2.8326 - y2_output_root_mean_squared_error: 3.4353 - val_loss: 58.1349 - val_y1_output_loss: 12.2280 - val_y2_output_loss: 45.9068 - val_y1_output_root_mean_squared_error: 3.4969 - val_y2_output_root_mean_squared_error: 6.7755
# Epoch 11/500
# 62/62 [==============================] - 1s 9ms/step - loss: 24.7721 - y1_output_loss: 8.8818 - y2_output_loss: 15.8903 - y1_output_root_mean_squared_error: 2.9802 - y2_output_root_mean_squared_error: 3.9863 - val_loss: 40.0384 - val_y1_output_loss: 10.2712 - val_y2_output_loss: 29.7672 - val_y1_output_root_mean_squared_error: 3.2049 - val_y2_output_root_mean_squared_error: 5.4559
# Epoch 12/500
# 62/62 [==============================] - 1s 9ms/step - loss: 19.5394 - y1_output_loss: 7.3888 - y2_output_loss: 12.1506 - y1_output_root_mean_squared_error: 2.7182 - y2_output_root_mean_squared_error: 3.4858 - val_loss: 24.4719 - val_y1_output_loss: 8.5119 - val_y2_output_loss: 15.9601 - val_y1_output_root_mean_squared_error: 2.9175 - val_y2_output_root_mean_squared_error: 3.9950
# Epoch 13/500
# 62/62 [==============================] - 0s 7ms/step - loss: 21.4939 - y1_output_loss: 7.8977 - y2_output_loss: 13.5962 - y1_output_root_mean_squared_error: 2.8103 - y2_output_root_mean_squared_error: 3.6873 - val_loss: 35.6276 - val_y1_output_loss: 13.6332 - val_y2_output_loss: 21.9944 - val_y1_output_root_mean_squared_error: 3.6923 - val_y2_output_root_mean_squared_error: 4.6898
# Epoch 14/500
# 62/62 [==============================] - 1s 11ms/step - loss: 20.2300 - y1_output_loss: 7.5726 - y2_output_loss: 12.6574 - y1_output_root_mean_squared_error: 2.7518 - y2_output_root_mean_squared_error: 3.5577 - val_loss: 13.6917 - val_y1_output_loss: 6.3027 - val_y2_output_loss: 7.3890 - val_y1_output_root_mean_squared_error: 2.5105 - val_y2_output_root_mean_squared_error: 2.7183
# Epoch 15/500
# 62/62 [==============================] - 0s 7ms/step - loss: 19.6195 - y1_output_loss: 7.4089 - y2_output_loss: 12.2106 - y1_output_root_mean_squared_error: 2.7219 - y2_output_root_mean_squared_error: 3.4944 - val_loss: 17.2448 - val_y1_output_loss: 8.1949 - val_y2_output_loss: 9.0499 - val_y1_output_root_mean_squared_error: 2.8627 - val_y2_output_root_mean_squared_error: 3.0083
# Epoch 16/500
# 62/62 [==============================] - 1s 8ms/step - loss: 23.4469 - y1_output_loss: 8.0010 - y2_output_loss: 15.4459 - y1_output_root_mean_squared_error: 2.8286 - y2_output_root_mean_squared_error: 3.9301 - val_loss: 19.6555 - val_y1_output_loss: 8.1894 - val_y2_output_loss: 11.4661 - val_y1_output_root_mean_squared_error: 2.8617 - val_y2_output_root_mean_squared_error: 3.3862
# Epoch 17/500
# 62/62 [==============================] - 1s 9ms/step - loss: 17.1890 - y1_output_loss: 6.4706 - y2_output_loss: 10.7183 - y1_output_root_mean_squared_error: 2.5437 - y2_output_root_mean_squared_error: 3.2739 - val_loss: 13.4132 - val_y1_output_loss: 5.9140 - val_y2_output_loss: 7.4993 - val_y1_output_root_mean_squared_error: 2.4319 - val_y2_output_root_mean_squared_error: 2.7385
# Epoch 18/500
# 62/62 [==============================] - 0s 7ms/step - loss: 17.2373 - y1_output_loss: 6.6574 - y2_output_loss: 10.5799 - y1_output_root_mean_squared_error: 2.5802 - y2_output_root_mean_squared_error: 3.2527 - val_loss: 51.7315 - val_y1_output_loss: 9.9008 - val_y2_output_loss: 41.8306 - val_y1_output_root_mean_squared_error: 3.1466 - val_y2_output_root_mean_squared_error: 6.4677
# Epoch 19/500
# 62/62 [==============================] - 1s 9ms/step - loss: 16.2596 - y1_output_loss: 6.1415 - y2_output_loss: 10.1181 - y1_output_root_mean_squared_error: 2.4782 - y2_output_root_mean_squared_error: 3.1809 - val_loss: 12.9702 - val_y1_output_loss: 6.0476 - val_y2_output_loss: 6.9225 - val_y1_output_root_mean_squared_error: 2.4592 - val_y2_output_root_mean_squared_error: 2.6311
# Epoch 20/500
# 62/62 [==============================] - 1s 11ms/step - loss: 16.2630 - y1_output_loss: 6.3425 - y2_output_loss: 9.9205 - y1_output_root_mean_squared_error: 2.5184 - y2_output_root_mean_squared_error: 3.1497 - val_loss: 13.0059 - val_y1_output_loss: 5.5808 - val_y2_output_loss: 7.4250 - val_y1_output_root_mean_squared_error: 2.3624 - val_y2_output_root_mean_squared_error: 2.7249
# Epoch 21/500
# 62/62 [==============================] - 1s 10ms/step - loss: 14.0998 - y1_output_loss: 5.5546 - y2_output_loss: 8.5452 - y1_output_root_mean_squared_error: 2.3568 - y2_output_root_mean_squared_error: 2.9232 - val_loss: 45.1527 - val_y1_output_loss: 15.8452 - val_y2_output_loss: 29.3075 - val_y1_output_root_mean_squared_error: 3.9806 - val_y2_output_root_mean_squared_error: 5.4136
# Epoch 22/500
# 62/62 [==============================] - 1s 12ms/step - loss: 16.4767 - y1_output_loss: 6.0207 - y2_output_loss: 10.4560 - y1_output_root_mean_squared_error: 2.4537 - y2_output_root_mean_squared_error: 3.2336 - val_loss: 11.9502 - val_y1_output_loss: 5.2917 - val_y2_output_loss: 6.6585 - val_y1_output_root_mean_squared_error: 2.3004 - val_y2_output_root_mean_squared_error: 2.5804
# Epoch 23/500
# 62/62 [==============================] - 1s 9ms/step - loss: 15.7468 - y1_output_loss: 5.8897 - y2_output_loss: 9.8571 - y1_output_root_mean_squared_error: 2.4269 - y2_output_root_mean_squared_error: 3.1396 - val_loss: 17.8191 - val_y1_output_loss: 5.4137 - val_y2_output_loss: 12.4054 - val_y1_output_root_mean_squared_error: 2.3267 - val_y2_output_root_mean_squared_error: 3.5221
# Epoch 24/500
# 62/62 [==============================] - 0s 8ms/step - loss: 13.7307 - y1_output_loss: 5.1991 - y2_output_loss: 8.5317 - y1_output_root_mean_squared_error: 2.2801 - y2_output_root_mean_squared_error: 2.9209 - val_loss: 22.2883 - val_y1_output_loss: 8.0319 - val_y2_output_loss: 14.2564 - val_y1_output_root_mean_squared_error: 2.8341 - val_y2_output_root_mean_squared_error: 3.7758
# Epoch 25/500
# 62/62 [==============================] - 1s 9ms/step - loss: 18.8264 - y1_output_loss: 6.5884 - y2_output_loss: 12.2380 - y1_output_root_mean_squared_error: 2.5668 - y2_output_root_mean_squared_error: 3.4983 - val_loss: 19.2176 - val_y1_output_loss: 7.9506 - val_y2_output_loss: 11.2670 - val_y1_output_root_mean_squared_error: 2.8197 - val_y2_output_root_mean_squared_error: 3.3566
# Epoch 26/500
# 62/62 [==============================] - 0s 7ms/step - loss: 16.4429 - y1_output_loss: 5.6813 - y2_output_loss: 10.7617 - y1_output_root_mean_squared_error: 2.3835 - y2_output_root_mean_squared_error: 3.2805 - val_loss: 21.3072 - val_y1_output_loss: 5.9347 - val_y2_output_loss: 15.3725 - val_y1_output_root_mean_squared_error: 2.4361 - val_y2_output_root_mean_squared_error: 3.9208
# Epoch 27/500
# 62/62 [==============================] - 1s 11ms/step - loss: 12.1928 - y1_output_loss: 4.3548 - y2_output_loss: 7.8380 - y1_output_root_mean_squared_error: 2.0868 - y2_output_root_mean_squared_error: 2.7996 - val_loss: 9.6721 - val_y1_output_loss: 3.8348 - val_y2_output_loss: 5.8373 - val_y1_output_root_mean_squared_error: 1.9583 - val_y2_output_root_mean_squared_error: 2.4161
# Epoch 28/500
# 62/62 [==============================] - 1s 8ms/step - loss: 15.2186 - y1_output_loss: 4.8696 - y2_output_loss: 10.3490 - y1_output_root_mean_squared_error: 2.2067 - y2_output_root_mean_squared_error: 3.2170 - val_loss: 28.8766 - val_y1_output_loss: 10.7730 - val_y2_output_loss: 18.1036 - val_y1_output_root_mean_squared_error: 3.2822 - val_y2_output_root_mean_squared_error: 4.2548
# Epoch 29/500
# 62/62 [==============================] - 1s 9ms/step - loss: 13.9467 - y1_output_loss: 4.6330 - y2_output_loss: 9.3137 - y1_output_root_mean_squared_error: 2.1524 - y2_output_root_mean_squared_error: 3.0518 - val_loss: 8.8848 - val_y1_output_loss: 3.7399 - val_y2_output_loss: 5.1449 - val_y1_output_root_mean_squared_error: 1.9339 - val_y2_output_root_mean_squared_error: 2.2682
# Epoch 30/500
# 62/62 [==============================] - 1s 9ms/step - loss: 10.9409 - y1_output_loss: 3.9212 - y2_output_loss: 7.0198 - y1_output_root_mean_squared_error: 1.9802 - y2_output_root_mean_squared_error: 2.6495 - val_loss: 21.0004 - val_y1_output_loss: 5.5437 - val_y2_output_loss: 15.4567 - val_y1_output_root_mean_squared_error: 2.3545 - val_y2_output_root_mean_squared_error: 3.9315
# Epoch 31/500
# 62/62 [==============================] - 1s 10ms/step - loss: 10.2217 - y1_output_loss: 3.6589 - y2_output_loss: 6.5628 - y1_output_root_mean_squared_error: 1.9128 - y2_output_root_mean_squared_error: 2.5618 - val_loss: 9.2283 - val_y1_output_loss: 4.1948 - val_y2_output_loss: 5.0336 - val_y1_output_root_mean_squared_error: 2.0481 - val_y2_output_root_mean_squared_error: 2.2436
# Epoch 32/500
# 62/62 [==============================] - 1s 8ms/step - loss: 10.1186 - y1_output_loss: 3.5660 - y2_output_loss: 6.5527 - y1_output_root_mean_squared_error: 1.8884 - y2_output_root_mean_squared_error: 2.5598 - val_loss: 17.3064 - val_y1_output_loss: 4.5353 - val_y2_output_loss: 12.7711 - val_y1_output_root_mean_squared_error: 2.1296 - val_y2_output_root_mean_squared_error: 3.5737
# Epoch 33/500
# 62/62 [==============================] - 1s 8ms/step - loss: 11.3319 - y1_output_loss: 3.6919 - y2_output_loss: 7.6400 - y1_output_root_mean_squared_error: 1.9214 - y2_output_root_mean_squared_error: 2.7641 - val_loss: 20.8449 - val_y1_output_loss: 4.7321 - val_y2_output_loss: 16.1128 - val_y1_output_root_mean_squared_error: 2.1753 - val_y2_output_root_mean_squared_error: 4.0141
# Epoch 34/500
# 62/62 [==============================] - 1s 14ms/step - loss: 7.8011 - y1_output_loss: 2.7343 - y2_output_loss: 5.0668 - y1_output_root_mean_squared_error: 1.6536 - y2_output_root_mean_squared_error: 2.2509 - val_loss: 9.3977 - val_y1_output_loss: 3.6813 - val_y2_output_loss: 5.7164 - val_y1_output_root_mean_squared_error: 1.9187 - val_y2_output_root_mean_squared_error: 2.3909
# Epoch 35/500
# 62/62 [==============================] - 0s 8ms/step - loss: 11.1453 - y1_output_loss: 3.6770 - y2_output_loss: 7.4683 - y1_output_root_mean_squared_error: 1.9175 - y2_output_root_mean_squared_error: 2.7328 - val_loss: 13.6595 - val_y1_output_loss: 3.1228 - val_y2_output_loss: 10.5367 - val_y1_output_root_mean_squared_error: 1.7671 - val_y2_output_root_mean_squared_error: 3.2460
# Epoch 36/500
# 62/62 [==============================] - 1s 9ms/step - loss: 9.5226 - y1_output_loss: 3.2203 - y2_output_loss: 6.3023 - y1_output_root_mean_squared_error: 1.7945 - y2_output_root_mean_squared_error: 2.5104 - val_loss: 37.3125 - val_y1_output_loss: 6.2215 - val_y2_output_loss: 31.0910 - val_y1_output_root_mean_squared_error: 2.4943 - val_y2_output_root_mean_squared_error: 5.5759
# Epoch 37/500
# 62/62 [==============================] - 1s 10ms/step - loss: 9.1728 - y1_output_loss: 3.0647 - y2_output_loss: 6.1081 - y1_output_root_mean_squared_error: 1.7506 - y2_output_root_mean_squared_error: 2.4715 - val_loss: 34.4734 - val_y1_output_loss: 7.7931 - val_y2_output_loss: 26.6803 - val_y1_output_root_mean_squared_error: 2.7916 - val_y2_output_root_mean_squared_error: 5.1653
# Epoch 38/500
# 62/62 [==============================] - 1s 14ms/step - loss: 9.2190 - y1_output_loss: 3.0345 - y2_output_loss: 6.1845 - y1_output_root_mean_squared_error: 1.7420 - y2_output_root_mean_squared_error: 2.4869 - val_loss: 7.3500 - val_y1_output_loss: 2.0748 - val_y2_output_loss: 5.2752 - val_y1_output_root_mean_squared_error: 1.4404 - val_y2_output_root_mean_squared_error: 2.2968
# Epoch 39/500
# 62/62 [==============================] - 1s 8ms/step - loss: 8.8676 - y1_output_loss: 3.0450 - y2_output_loss: 5.8226 - y1_output_root_mean_squared_error: 1.7450 - y2_output_root_mean_squared_error: 2.4130 - val_loss: 7.5829 - val_y1_output_loss: 2.4010 - val_y2_output_loss: 5.1818 - val_y1_output_root_mean_squared_error: 1.5495 - val_y2_output_root_mean_squared_error: 2.2764
# Epoch 40/500
# 62/62 [==============================] - 0s 7ms/step - loss: 8.7213 - y1_output_loss: 3.0949 - y2_output_loss: 5.6263 - y1_output_root_mean_squared_error: 1.7592 - y2_output_root_mean_squared_error: 2.3720 - val_loss: 42.6021 - val_y1_output_loss: 8.5125 - val_y2_output_loss: 34.0897 - val_y1_output_root_mean_squared_error: 2.9176 - val_y2_output_root_mean_squared_error: 5.8386
# Epoch 41/500
# 62/62 [==============================] - 1s 13ms/step - loss: 11.3582 - y1_output_loss: 3.4154 - y2_output_loss: 7.9428 - y1_output_root_mean_squared_error: 1.8481 - y2_output_root_mean_squared_error: 2.8183 - val_loss: 13.7420 - val_y1_output_loss: 4.1794 - val_y2_output_loss: 9.5626 - val_y1_output_root_mean_squared_error: 2.0443 - val_y2_output_root_mean_squared_error: 3.0924
# Epoch 42/500
# 62/62 [==============================] - 1s 17ms/step - loss: 7.7309 - y1_output_loss: 2.7114 - y2_output_loss: 5.0195 - y1_output_root_mean_squared_error: 1.6466 - y2_output_root_mean_squared_error: 2.2404 - val_loss: 9.2413 - val_y1_output_loss: 3.3576 - val_y2_output_loss: 5.8836 - val_y1_output_root_mean_squared_error: 1.8324 - val_y2_output_root_mean_squared_error: 2.4256
# Epoch 43/500
# 62/62 [==============================] - 1s 10ms/step - loss: 8.9066 - y1_output_loss: 2.8541 - y2_output_loss: 6.0525 - y1_output_root_mean_squared_error: 1.6894 - y2_output_root_mean_squared_error: 2.4602 - val_loss: 14.4434 - val_y1_output_loss: 5.5203 - val_y2_output_loss: 8.9231 - val_y1_output_root_mean_squared_error: 2.3495 - val_y2_output_root_mean_squared_error: 2.9872
# Epoch 44/500
# 62/62 [==============================] - 1s 10ms/step - loss: 7.7797 - y1_output_loss: 2.5432 - y2_output_loss: 5.2366 - y1_output_root_mean_squared_error: 1.5947 - y2_output_root_mean_squared_error: 2.2884 - val_loss: 8.1534 - val_y1_output_loss: 3.1316 - val_y2_output_loss: 5.0218 - val_y1_output_root_mean_squared_error: 1.7696 - val_y2_output_root_mean_squared_error: 2.2409
# Epoch 45/500
# 62/62 [==============================] - 0s 6ms/step - loss: 7.6720 - y1_output_loss: 2.4665 - y2_output_loss: 5.2055 - y1_output_root_mean_squared_error: 1.5705 - y2_output_root_mean_squared_error: 2.2815 - val_loss: 16.5002 - val_y1_output_loss: 4.0594 - val_y2_output_loss: 12.4408 - val_y1_output_root_mean_squared_error: 2.0148 - val_y2_output_root_mean_squared_error: 3.5272
# Epoch 46/500
# 62/62 [==============================] - 0s 8ms/step - loss: 9.2624 - y1_output_loss: 3.0233 - y2_output_loss: 6.2391 - y1_output_root_mean_squared_error: 1.7388 - y2_output_root_mean_squared_error: 2.4978 - val_loss: 8.6400 - val_y1_output_loss: 2.2549 - val_y2_output_loss: 6.3850 - val_y1_output_root_mean_squared_error: 1.5016 - val_y2_output_root_mean_squared_error: 2.5269
# Epoch 47/500
# 62/62 [==============================] - 0s 5ms/step - loss: 9.2983 - y1_output_loss: 2.7578 - y2_output_loss: 6.5405 - y1_output_root_mean_squared_error: 1.6607 - y2_output_root_mean_squared_error: 2.5574 - val_loss: 14.3302 - val_y1_output_loss: 4.5373 - val_y2_output_loss: 9.7929 - val_y1_output_root_mean_squared_error: 2.1301 - val_y2_output_root_mean_squared_error: 3.1294
# Epoch 48/500
# 62/62 [==============================] - 0s 7ms/step - loss: 7.0928 - y1_output_loss: 2.2705 - y2_output_loss: 4.8223 - y1_output_root_mean_squared_error: 1.5068 - y2_output_root_mean_squared_error: 2.1960 - val_loss: 7.8822 - val_y1_output_loss: 2.3925 - val_y2_output_loss: 5.4898 - val_y1_output_root_mean_squared_error: 1.5468 - val_y2_output_root_mean_squared_error: 2.3430
# Epoch 49/500
# 62/62 [==============================] - 0s 6ms/step - loss: 7.0582 - y1_output_loss: 2.2340 - y2_output_loss: 4.8242 - y1_output_root_mean_squared_error: 1.4947 - y2_output_root_mean_squared_error: 2.1964 - val_loss: 7.2577 - val_y1_output_loss: 2.0094 - val_y2_output_loss: 5.2483 - val_y1_output_root_mean_squared_error: 1.4175 - val_y2_output_root_mean_squared_error: 2.2909
# Epoch 50/500
# 62/62 [==============================] - 0s 7ms/step - loss: 8.2661 - y1_output_loss: 2.5988 - y2_output_loss: 5.6673 - y1_output_root_mean_squared_error: 1.6121 - y2_output_root_mean_squared_error: 2.3806 - val_loss: 9.4739 - val_y1_output_loss: 3.6486 - val_y2_output_loss: 5.8253 - val_y1_output_root_mean_squared_error: 1.9101 - val_y2_output_root_mean_squared_error: 2.4136
# Epoch 51/500
# 62/62 [==============================] - 0s 6ms/step - loss: 7.2793 - y1_output_loss: 2.2878 - y2_output_loss: 4.9915 - y1_output_root_mean_squared_error: 1.5125 - y2_output_root_mean_squared_error: 2.2342 - val_loss: 10.1464 - val_y1_output_loss: 2.6043 - val_y2_output_loss: 7.5421 - val_y1_output_root_mean_squared_error: 1.6138 - val_y2_output_root_mean_squared_error: 2.7463
# Epoch 52/500
# 62/62 [==============================] - 0s 7ms/step - loss: 7.4881 - y1_output_loss: 2.3427 - y2_output_loss: 5.1454 - y1_output_root_mean_squared_error: 1.5306 - y2_output_root_mean_squared_error: 2.2683 - val_loss: 7.3745 - val_y1_output_loss: 2.0790 - val_y2_output_loss: 5.2956 - val_y1_output_root_mean_squared_error: 1.4419 - val_y2_output_root_mean_squared_error: 2.3012
# Epoch 53/500
# 62/62 [==============================] - 1s 9ms/step - loss: 10.2729 - y1_output_loss: 3.0475 - y2_output_loss: 7.2254 - y1_output_root_mean_squared_error: 1.7457 - y2_output_root_mean_squared_error: 2.6880 - val_loss: 9.1449 - val_y1_output_loss: 3.1848 - val_y2_output_loss: 5.9602 - val_y1_output_root_mean_squared_error: 1.7846 - val_y2_output_root_mean_squared_error: 2.4413
# Epoch 54/500
# 62/62 [==============================] - 0s 5ms/step - loss: 7.6405 - y1_output_loss: 2.4172 - y2_output_loss: 5.2233 - y1_output_root_mean_squared_error: 1.5547 - y2_output_root_mean_squared_error: 2.2855 - val_loss: 5.5125 - val_y1_output_loss: 1.6310 - val_y2_output_loss: 3.8815 - val_y1_output_root_mean_squared_error: 1.2771 - val_y2_output_root_mean_squared_error: 1.9701
# Epoch 55/500
# 62/62 [==============================] - 0s 5ms/step - loss: 5.9800 - y1_output_loss: 1.8031 - y2_output_loss: 4.1769 - y1_output_root_mean_squared_error: 1.3428 - y2_output_root_mean_squared_error: 2.0437 - val_loss: 10.8453 - val_y1_output_loss: 3.7103 - val_y2_output_loss: 7.1351 - val_y1_output_root_mean_squared_error: 1.9262 - val_y2_output_root_mean_squared_error: 2.6712
# Epoch 56/500
# 62/62 [==============================] - 1s 9ms/step - loss: 6.8383 - y1_output_loss: 2.1710 - y2_output_loss: 4.6672 - y1_output_root_mean_squared_error: 1.4734 - y2_output_root_mean_squared_error: 2.1604 - val_loss: 24.8193 - val_y1_output_loss: 7.1170 - val_y2_output_loss: 17.7023 - val_y1_output_root_mean_squared_error: 2.6678 - val_y2_output_root_mean_squared_error: 4.2074
# Epoch 57/500
# 62/62 [==============================] - 0s 5ms/step - loss: 6.9532 - y1_output_loss: 2.0819 - y2_output_loss: 4.8713 - y1_output_root_mean_squared_error: 1.4429 - y2_output_root_mean_squared_error: 2.2071 - val_loss: 5.8177 - val_y1_output_loss: 1.7251 - val_y2_output_loss: 4.0926 - val_y1_output_root_mean_squared_error: 1.3134 - val_y2_output_root_mean_squared_error: 2.0230
# Epoch 58/500
# 62/62 [==============================] - 0s 6ms/step - loss: 7.8994 - y1_output_loss: 2.2927 - y2_output_loss: 5.6067 - y1_output_root_mean_squared_error: 1.5142 - y2_output_root_mean_squared_error: 2.3678 - val_loss: 7.2888 - val_y1_output_loss: 1.6979 - val_y2_output_loss: 5.5908 - val_y1_output_root_mean_squared_error: 1.3030 - val_y2_output_root_mean_squared_error: 2.3645
# Epoch 59/500
# 62/62 [==============================] - 0s 7ms/step - loss: 6.1617 - y1_output_loss: 1.7908 - y2_output_loss: 4.3708 - y1_output_root_mean_squared_error: 1.3382 - y2_output_root_mean_squared_error: 2.0907 - val_loss: 89.4076 - val_y1_output_loss: 23.2140 - val_y2_output_loss: 66.1936 - val_y1_output_root_mean_squared_error: 4.8181 - val_y2_output_root_mean_squared_error: 8.1359
# Epoch 60/500
# 62/62 [==============================] - 0s 6ms/step - loss: 8.3382 - y1_output_loss: 2.5656 - y2_output_loss: 5.7726 - y1_output_root_mean_squared_error: 1.6017 - y2_output_root_mean_squared_error: 2.4026 - val_loss: 5.5481 - val_y1_output_loss: 1.8409 - val_y2_output_loss: 3.7072 - val_y1_output_root_mean_squared_error: 1.3568 - val_y2_output_root_mean_squared_error: 1.9254
# Epoch 61/500
# 62/62 [==============================] - 0s 5ms/step - loss: 6.0896 - y1_output_loss: 1.6910 - y2_output_loss: 4.3986 - y1_output_root_mean_squared_error: 1.3004 - y2_output_root_mean_squared_error: 2.0973 - val_loss: 30.9054 - val_y1_output_loss: 12.4291 - val_y2_output_loss: 18.4764 - val_y1_output_root_mean_squared_error: 3.5255 - val_y2_output_root_mean_squared_error: 4.2984
# Epoch 62/500
# 62/62 [==============================] - 0s 6ms/step - loss: 7.0128 - y1_output_loss: 1.9378 - y2_output_loss: 5.0750 - y1_output_root_mean_squared_error: 1.3921 - y2_output_root_mean_squared_error: 2.2528 - val_loss: 6.5811 - val_y1_output_loss: 2.2104 - val_y2_output_loss: 4.3707 - val_y1_output_root_mean_squared_error: 1.4867 - val_y2_output_root_mean_squared_error: 2.0906
# Epoch 63/500
# 62/62 [==============================] - 0s 6ms/step - loss: 10.6664 - y1_output_loss: 3.0736 - y2_output_loss: 7.5928 - y1_output_root_mean_squared_error: 1.7532 - y2_output_root_mean_squared_error: 2.7555 - val_loss: 4.7826 - val_y1_output_loss: 1.1072 - val_y2_output_loss: 3.6753 - val_y1_output_root_mean_squared_error: 1.0522 - val_y2_output_root_mean_squared_error: 1.9171
# Epoch 64/500
# 62/62 [==============================] - 0s 6ms/step - loss: 4.2750 - y1_output_loss: 1.2110 - y2_output_loss: 3.0640 - y1_output_root_mean_squared_error: 1.1005 - y2_output_root_mean_squared_error: 1.7504 - val_loss: 7.3075 - val_y1_output_loss: 2.1564 - val_y2_output_loss: 5.1511 - val_y1_output_root_mean_squared_error: 1.4685 - val_y2_output_root_mean_squared_error: 2.2696
# Epoch 65/500
# 62/62 [==============================] - 0s 7ms/step - loss: 5.8843 - y1_output_loss: 1.7061 - y2_output_loss: 4.1782 - y1_output_root_mean_squared_error: 1.3062 - y2_output_root_mean_squared_error: 2.0441 - val_loss: 15.2829 - val_y1_output_loss: 2.4552 - val_y2_output_loss: 12.8276 - val_y1_output_root_mean_squared_error: 1.5669 - val_y2_output_root_mean_squared_error: 3.5816
# Epoch 66/500
# 62/62 [==============================] - 0s 7ms/step - loss: 8.4214 - y1_output_loss: 2.4259 - y2_output_loss: 5.9955 - y1_output_root_mean_squared_error: 1.5575 - y2_output_root_mean_squared_error: 2.4486 - val_loss: 6.5756 - val_y1_output_loss: 1.5627 - val_y2_output_loss: 5.0129 - val_y1_output_root_mean_squared_error: 1.2501 - val_y2_output_root_mean_squared_error: 2.2390
# Epoch 67/500
# 62/62 [==============================] - 0s 6ms/step - loss: 4.5199 - y1_output_loss: 1.2566 - y2_output_loss: 3.2633 - y1_output_root_mean_squared_error: 1.1210 - y2_output_root_mean_squared_error: 1.8065 - val_loss: 4.1599 - val_y1_output_loss: 0.9084 - val_y2_output_loss: 3.2516 - val_y1_output_root_mean_squared_error: 0.9531 - val_y2_output_root_mean_squared_error: 1.8032
# Epoch 68/500
# 62/62 [==============================] - 0s 7ms/step - loss: 4.0548 - y1_output_loss: 1.0656 - y2_output_loss: 2.9892 - y1_output_root_mean_squared_error: 1.0323 - y2_output_root_mean_squared_error: 1.7289 - val_loss: 4.2230 - val_y1_output_loss: 1.1053 - val_y2_output_loss: 3.1178 - val_y1_output_root_mean_squared_error: 1.0513 - val_y2_output_root_mean_squared_error: 1.7657
# Epoch 69/500
# 62/62 [==============================] - 0s 7ms/step - loss: 4.1991 - y1_output_loss: 0.9450 - y2_output_loss: 3.2541 - y1_output_root_mean_squared_error: 0.9721 - y2_output_root_mean_squared_error: 1.8039 - val_loss: 3.6131 - val_y1_output_loss: 0.8436 - val_y2_output_loss: 2.7695 - val_y1_output_root_mean_squared_error: 0.9185 - val_y2_output_root_mean_squared_error: 1.6642
# Epoch 70/500
# 62/62 [==============================] - 0s 7ms/step - loss: 3.8524 - y1_output_loss: 0.9773 - y2_output_loss: 2.8751 - y1_output_root_mean_squared_error: 0.9886 - y2_output_root_mean_squared_error: 1.6956 - val_loss: 11.2328 - val_y1_output_loss: 2.6988 - val_y2_output_loss: 8.5340 - val_y1_output_root_mean_squared_error: 1.6428 - val_y2_output_root_mean_squared_error: 2.9213
# Epoch 71/500
# 62/62 [==============================] - 1s 11ms/step - loss: 4.3558 - y1_output_loss: 1.1305 - y2_output_loss: 3.2253 - y1_output_root_mean_squared_error: 1.0633 - y2_output_root_mean_squared_error: 1.7959 - val_loss: 49.7918 - val_y1_output_loss: 14.9727 - val_y2_output_loss: 34.8191 - val_y1_output_root_mean_squared_error: 3.8695 - val_y2_output_root_mean_squared_error: 5.9008
# Epoch 72/500
# 62/62 [==============================] - 1s 8ms/step - loss: 4.6747 - y1_output_loss: 1.2582 - y2_output_loss: 3.4165 - y1_output_root_mean_squared_error: 1.1217 - y2_output_root_mean_squared_error: 1.8484 - val_loss: 5.4860 - val_y1_output_loss: 2.0478 - val_y2_output_loss: 3.4382 - val_y1_output_root_mean_squared_error: 1.4310 - val_y2_output_root_mean_squared_error: 1.8542
# Epoch 73/500
# 62/62 [==============================] - 1s 8ms/step - loss: 3.9971 - y1_output_loss: 1.0396 - y2_output_loss: 2.9575 - y1_output_root_mean_squared_error: 1.0196 - y2_output_root_mean_squared_error: 1.7197 - val_loss: 3.6595 - val_y1_output_loss: 0.7841 - val_y2_output_loss: 2.8753 - val_y1_output_root_mean_squared_error: 0.8855 - val_y2_output_root_mean_squared_error: 1.6957
# Epoch 74/500
# 62/62 [==============================] - 0s 7ms/step - loss: 4.7728 - y1_output_loss: 1.2550 - y2_output_loss: 3.5178 - y1_output_root_mean_squared_error: 1.1203 - y2_output_root_mean_squared_error: 1.8756 - val_loss: 3.9656 - val_y1_output_loss: 0.9859 - val_y2_output_loss: 2.9797 - val_y1_output_root_mean_squared_error: 0.9929 - val_y2_output_root_mean_squared_error: 1.7262
# Epoch 75/500
# 62/62 [==============================] - 0s 6ms/step - loss: 3.3305 - y1_output_loss: 0.7922 - y2_output_loss: 2.5384 - y1_output_root_mean_squared_error: 0.8900 - y2_output_root_mean_squared_error: 1.5932 - val_loss: 4.6796 - val_y1_output_loss: 1.5215 - val_y2_output_loss: 3.1581 - val_y1_output_root_mean_squared_error: 1.2335 - val_y2_output_root_mean_squared_error: 1.7771
# Epoch 76/500
# 62/62 [==============================] - 1s 8ms/step - loss: 7.4153 - y1_output_loss: 2.0007 - y2_output_loss: 5.4146 - y1_output_root_mean_squared_error: 1.4145 - y2_output_root_mean_squared_error: 2.3269 - val_loss: 4.4231 - val_y1_output_loss: 1.0420 - val_y2_output_loss: 3.3812 - val_y1_output_root_mean_squared_error: 1.0208 - val_y2_output_root_mean_squared_error: 1.8388
# Epoch 77/500
# 62/62 [==============================] - 1s 9ms/step - loss: 5.8636 - y1_output_loss: 1.7855 - y2_output_loss: 4.0781 - y1_output_root_mean_squared_error: 1.3362 - y2_output_root_mean_squared_error: 2.0194 - val_loss: 6.4966 - val_y1_output_loss: 2.0046 - val_y2_output_loss: 4.4920 - val_y1_output_root_mean_squared_error: 1.4158 - val_y2_output_root_mean_squared_error: 2.1194
# Epoch 78/500
# 62/62 [==============================] - 1s 9ms/step - loss: 6.5758 - y1_output_loss: 1.6748 - y2_output_loss: 4.9010 - y1_output_root_mean_squared_error: 1.2941 - y2_output_root_mean_squared_error: 2.2138 - val_loss: 3.7776 - val_y1_output_loss: 0.7254 - val_y2_output_loss: 3.0523 - val_y1_output_root_mean_squared_error: 0.8517 - val_y2_output_root_mean_squared_error: 1.7471
# Epoch 79/500
# 62/62 [==============================] - 1s 11ms/step - loss: 4.3060 - y1_output_loss: 1.0176 - y2_output_loss: 3.2884 - y1_output_root_mean_squared_error: 1.0087 - y2_output_root_mean_squared_error: 1.8134 - val_loss: 6.7541 - val_y1_output_loss: 1.5139 - val_y2_output_loss: 5.2402 - val_y1_output_root_mean_squared_error: 1.2304 - val_y2_output_root_mean_squared_error: 2.2891
# Epoch 80/500
# 62/62 [==============================] - 1s 8ms/step - loss: 8.8597 - y1_output_loss: 2.7597 - y2_output_loss: 6.1000 - y1_output_root_mean_squared_error: 1.6612 - y2_output_root_mean_squared_error: 2.4698 - val_loss: 9.8880 - val_y1_output_loss: 1.1189 - val_y2_output_loss: 8.7691 - val_y1_output_root_mean_squared_error: 1.0578 - val_y2_output_root_mean_squared_error: 2.9613
# Epoch 81/500
# 62/62 [==============================] - 1s 8ms/step - loss: 3.5449 - y1_output_loss: 0.7276 - y2_output_loss: 2.8173 - y1_output_root_mean_squared_error: 0.8530 - y2_output_root_mean_squared_error: 1.6785 - val_loss: 3.0559 - val_y1_output_loss: 0.6563 - val_y2_output_loss: 2.3995 - val_y1_output_root_mean_squared_error: 0.8102 - val_y2_output_root_mean_squared_error: 1.5490
# Epoch 82/500
# 62/62 [==============================] - 1s 19ms/step - loss: 3.6524 - y1_output_loss: 0.8462 - y2_output_loss: 2.8062 - y1_output_root_mean_squared_error: 0.9199 - y2_output_root_mean_squared_error: 1.6752 - val_loss: 4.9152 - val_y1_output_loss: 0.7493 - val_y2_output_loss: 4.1659 - val_y1_output_root_mean_squared_error: 0.8656 - val_y2_output_root_mean_squared_error: 2.0410
# Epoch 83/500
# 62/62 [==============================] - 1s 21ms/step - loss: 4.3019 - y1_output_loss: 1.1039 - y2_output_loss: 3.1980 - y1_output_root_mean_squared_error: 1.0507 - y2_output_root_mean_squared_error: 1.7883 - val_loss: 4.4001 - val_y1_output_loss: 0.6555 - val_y2_output_loss: 3.7446 - val_y1_output_root_mean_squared_error: 0.8096 - val_y2_output_root_mean_squared_error: 1.9351
# Epoch 84/500
# 62/62 [==============================] - 1s 13ms/step - loss: 3.4176 - y1_output_loss: 0.7786 - y2_output_loss: 2.6390 - y1_output_root_mean_squared_error: 0.8824 - y2_output_root_mean_squared_error: 1.6245 - val_loss: 8.2951 - val_y1_output_loss: 1.1661 - val_y2_output_loss: 7.1290 - val_y1_output_root_mean_squared_error: 1.0799 - val_y2_output_root_mean_squared_error: 2.6700
# Epoch 85/500
# 62/62 [==============================] - 1s 11ms/step - loss: 3.2855 - y1_output_loss: 0.7032 - y2_output_loss: 2.5823 - y1_output_root_mean_squared_error: 0.8386 - y2_output_root_mean_squared_error: 1.6070 - val_loss: 3.1674 - val_y1_output_loss: 0.6530 - val_y2_output_loss: 2.5144 - val_y1_output_root_mean_squared_error: 0.8081 - val_y2_output_root_mean_squared_error: 1.5857
# Epoch 86/500
# 62/62 [==============================] - 2s 28ms/step - loss: 3.2791 - y1_output_loss: 0.7444 - y2_output_loss: 2.5348 - y1_output_root_mean_squared_error: 0.8628 - y2_output_root_mean_squared_error: 1.5921 - val_loss: 4.7349 - val_y1_output_loss: 0.6202 - val_y2_output_loss: 4.1147 - val_y1_output_root_mean_squared_error: 0.7875 - val_y2_output_root_mean_squared_error: 2.0285
# Epoch 87/500
# 62/62 [==============================] - 1s 14ms/step - loss: 3.5684 - y1_output_loss: 0.8010 - y2_output_loss: 2.7674 - y1_output_root_mean_squared_error: 0.8950 - y2_output_root_mean_squared_error: 1.6635 - val_loss: 3.7730 - val_y1_output_loss: 0.8100 - val_y2_output_loss: 2.9630 - val_y1_output_root_mean_squared_error: 0.9000 - val_y2_output_root_mean_squared_error: 1.7213
# Epoch 88/500
# 62/62 [==============================] - 1s 10ms/step - loss: 3.3597 - y1_output_loss: 0.6078 - y2_output_loss: 2.7519 - y1_output_root_mean_squared_error: 0.7796 - y2_output_root_mean_squared_error: 1.6589 - val_loss: 7.7738 - val_y1_output_loss: 1.3917 - val_y2_output_loss: 6.3821 - val_y1_output_root_mean_squared_error: 1.1797 - val_y2_output_root_mean_squared_error: 2.5263
# Epoch 89/500
# 62/62 [==============================] - 1s 9ms/step - loss: 2.9492 - y1_output_loss: 0.6287 - y2_output_loss: 2.3206 - y1_output_root_mean_squared_error: 0.7929 - y2_output_root_mean_squared_error: 1.5233 - val_loss: 3.9744 - val_y1_output_loss: 0.5491 - val_y2_output_loss: 3.4252 - val_y1_output_root_mean_squared_error: 0.7410 - val_y2_output_root_mean_squared_error: 1.8507
# Epoch 90/500
# 62/62 [==============================] - 1s 13ms/step - loss: 3.3453 - y1_output_loss: 0.7267 - y2_output_loss: 2.6186 - y1_output_root_mean_squared_error: 0.8524 - y2_output_root_mean_squared_error: 1.6182 - val_loss: 6.4837 - val_y1_output_loss: 0.9266 - val_y2_output_loss: 5.5571 - val_y1_output_root_mean_squared_error: 0.9626 - val_y2_output_root_mean_squared_error: 2.3573
# Epoch 91/500
# 62/62 [==============================] - 1s 9ms/step - loss: 3.3947 - y1_output_loss: 0.6580 - y2_output_loss: 2.7367 - y1_output_root_mean_squared_error: 0.8112 - y2_output_root_mean_squared_error: 1.6543 - val_loss: 2.8125 - val_y1_output_loss: 0.6718 - val_y2_output_loss: 2.1407 - val_y1_output_root_mean_squared_error: 0.8196 - val_y2_output_root_mean_squared_error: 1.4631
# Epoch 92/500
# 62/62 [==============================] - 1s 10ms/step - loss: 2.9886 - y1_output_loss: 0.6546 - y2_output_loss: 2.3340 - y1_output_root_mean_squared_error: 0.8091 - y2_output_root_mean_squared_error: 1.5278 - val_loss: 2.8526 - val_y1_output_loss: 0.4966 - val_y2_output_loss: 2.3561 - val_y1_output_root_mean_squared_error: 0.7047 - val_y2_output_root_mean_squared_error: 1.5349
# Epoch 93/500
# 62/62 [==============================] - 1s 8ms/step - loss: 2.5926 - y1_output_loss: 0.4488 - y2_output_loss: 2.1437 - y1_output_root_mean_squared_error: 0.6700 - y2_output_root_mean_squared_error: 1.4641 - val_loss: 2.8490 - val_y1_output_loss: 0.5316 - val_y2_output_loss: 2.3174 - val_y1_output_root_mean_squared_error: 0.7291 - val_y2_output_root_mean_squared_error: 1.5223
# Epoch 94/500
# 62/62 [==============================] - 1s 12ms/step - loss: 3.2020 - y1_output_loss: 0.6946 - y2_output_loss: 2.5074 - y1_output_root_mean_squared_error: 0.8334 - y2_output_root_mean_squared_error: 1.5835 - val_loss: 19.0875 - val_y1_output_loss: 1.9887 - val_y2_output_loss: 17.0987 - val_y1_output_root_mean_squared_error: 1.4102 - val_y2_output_root_mean_squared_error: 4.1351
# Epoch 95/500
# 62/62 [==============================] - 1s 8ms/step - loss: 3.0500 - y1_output_loss: 0.6646 - y2_output_loss: 2.3853 - y1_output_root_mean_squared_error: 0.8153 - y2_output_root_mean_squared_error: 1.5444 - val_loss: 7.2601 - val_y1_output_loss: 2.1147 - val_y2_output_loss: 5.1454 - val_y1_output_root_mean_squared_error: 1.4542 - val_y2_output_root_mean_squared_error: 2.2683
# Epoch 96/500
# 62/62 [==============================] - 1s 10ms/step - loss: 5.1327 - y1_output_loss: 1.3184 - y2_output_loss: 3.8143 - y1_output_root_mean_squared_error: 1.1482 - y2_output_root_mean_squared_error: 1.9530 - val_loss: 4.6134 - val_y1_output_loss: 1.7621 - val_y2_output_loss: 2.8513 - val_y1_output_root_mean_squared_error: 1.3274 - val_y2_output_root_mean_squared_error: 1.6886
# Epoch 97/500
# 62/62 [==============================] - 0s 8ms/step - loss: 3.1097 - y1_output_loss: 0.6538 - y2_output_loss: 2.4558 - y1_output_root_mean_squared_error: 0.8086 - y2_output_root_mean_squared_error: 1.5671 - val_loss: 2.8449 - val_y1_output_loss: 0.6063 - val_y2_output_loss: 2.2386 - val_y1_output_root_mean_squared_error: 0.7786 - val_y2_output_root_mean_squared_error: 1.4962
# Epoch 98/500
# 62/62 [==============================] - 1s 17ms/step - loss: 3.7500 - y1_output_loss: 0.8008 - y2_output_loss: 2.9492 - y1_output_root_mean_squared_error: 0.8949 - y2_output_root_mean_squared_error: 1.7173 - val_loss: 3.4467 - val_y1_output_loss: 1.0211 - val_y2_output_loss: 2.4256 - val_y1_output_root_mean_squared_error: 1.0105 - val_y2_output_root_mean_squared_error: 1.5574
# Epoch 99/500
# 62/62 [==============================] - 1s 10ms/step - loss: 2.9517 - y1_output_loss: 0.6532 - y2_output_loss: 2.2986 - y1_output_root_mean_squared_error: 0.8082 - y2_output_root_mean_squared_error: 1.5161 - val_loss: 3.2832 - val_y1_output_loss: 0.7002 - val_y2_output_loss: 2.5830 - val_y1_output_root_mean_squared_error: 0.8368 - val_y2_output_root_mean_squared_error: 1.6072
# Epoch 100/500
# 62/62 [==============================] - 0s 8ms/step - loss: 2.7055 - y1_output_loss: 0.5671 - y2_output_loss: 2.1385 - y1_output_root_mean_squared_error: 0.7530 - y2_output_root_mean_squared_error: 1.4623 - val_loss: 4.4928 - val_y1_output_loss: 0.8528 - val_y2_output_loss: 3.6400 - val_y1_output_root_mean_squared_error: 0.9234 - val_y2_output_root_mean_squared_error: 1.9079
# Epoch 101/500
# 62/62 [==============================] - 1s 9ms/step - loss: 2.6683 - y1_output_loss: 0.5768 - y2_output_loss: 2.0914 - y1_output_root_mean_squared_error: 0.7595 - y2_output_root_mean_squared_error: 1.4462 - val_loss: 3.2433 - val_y1_output_loss: 0.6465 - val_y2_output_loss: 2.5968 - val_y1_output_root_mean_squared_error: 0.8040 - val_y2_output_root_mean_squared_error: 1.6115
# Epoch 102/500
# 62/62 [==============================] - 0s 8ms/step - loss: 3.3272 - y1_output_loss: 0.6268 - y2_output_loss: 2.7004 - y1_output_root_mean_squared_error: 0.7917 - y2_output_root_mean_squared_error: 1.6433 - val_loss: 4.6777 - val_y1_output_loss: 1.0582 - val_y2_output_loss: 3.6195 - val_y1_output_root_mean_squared_error: 1.0287 - val_y2_output_root_mean_squared_error: 1.9025
# Epoch 103/500
# 62/62 [==============================] - 1s 11ms/step - loss: 2.9011 - y1_output_loss: 0.6488 - y2_output_loss: 2.2523 - y1_output_root_mean_squared_error: 0.8055 - y2_output_root_mean_squared_error: 1.5008 - val_loss: 4.5787 - val_y1_output_loss: 1.2752 - val_y2_output_loss: 3.3036 - val_y1_output_root_mean_squared_error: 1.1292 - val_y2_output_root_mean_squared_error: 1.8176
# Epoch 104/500
# 62/62 [==============================] - 0s 8ms/step - loss: 2.7461 - y1_output_loss: 0.5046 - y2_output_loss: 2.2415 - y1_output_root_mean_squared_error: 0.7103 - y2_output_root_mean_squared_error: 1.4972 - val_loss: 68.7168 - val_y1_output_loss: 18.0490 - val_y2_output_loss: 50.6678 - val_y1_output_root_mean_squared_error: 4.2484 - val_y2_output_root_mean_squared_error: 7.1181
# Epoch 105/500
# 62/62 [==============================] - 1s 9ms/step - loss: 3.7698 - y1_output_loss: 0.9599 - y2_output_loss: 2.8099 - y1_output_root_mean_squared_error: 0.9797 - y2_output_root_mean_squared_error: 1.6763 - val_loss: 3.9973 - val_y1_output_loss: 0.9493 - val_y2_output_loss: 3.0480 - val_y1_output_root_mean_squared_error: 0.9743 - val_y2_output_root_mean_squared_error: 1.7458
# Epoch 106/500
# 62/62 [==============================] - 1s 8ms/step - loss: 6.7071 - y1_output_loss: 1.5730 - y2_output_loss: 5.1341 - y1_output_root_mean_squared_error: 1.2542 - y2_output_root_mean_squared_error: 2.2659 - val_loss: 4.3798 - val_y1_output_loss: 1.2791 - val_y2_output_loss: 3.1007 - val_y1_output_root_mean_squared_error: 1.1310 - val_y2_output_root_mean_squared_error: 1.7609
# Epoch 107/500
# 62/62 [==============================] - 1s 13ms/step - loss: 2.9111 - y1_output_loss: 0.6773 - y2_output_loss: 2.2338 - y1_output_root_mean_squared_error: 0.8230 - y2_output_root_mean_squared_error: 1.4946 - val_loss: 3.0245 - val_y1_output_loss: 0.6603 - val_y2_output_loss: 2.3641 - val_y1_output_root_mean_squared_error: 0.8126 - val_y2_output_root_mean_squared_error: 1.5376
# Epoch 108/500
# 62/62 [==============================] - 1s 9ms/step - loss: 5.7831 - y1_output_loss: 1.5146 - y2_output_loss: 4.2685 - y1_output_root_mean_squared_error: 1.2307 - y2_output_root_mean_squared_error: 2.0660 - val_loss: 11.0186 - val_y1_output_loss: 1.2518 - val_y2_output_loss: 9.7668 - val_y1_output_root_mean_squared_error: 1.1188 - val_y2_output_root_mean_squared_error: 3.1252
# Epoch 109/500
# 62/62 [==============================] - 1s 9ms/step - loss: 2.9313 - y1_output_loss: 0.5899 - y2_output_loss: 2.3414 - y1_output_root_mean_squared_error: 0.7681 - y2_output_root_mean_squared_error: 1.5302 - val_loss: 2.7756 - val_y1_output_loss: 0.4795 - val_y2_output_loss: 2.2961 - val_y1_output_root_mean_squared_error: 0.6925 - val_y2_output_root_mean_squared_error: 1.5153
# Epoch 110/500
# 62/62 [==============================] - 1s 10ms/step - loss: 2.5106 - y1_output_loss: 0.4686 - y2_output_loss: 2.0421 - y1_output_root_mean_squared_error: 0.6845 - y2_output_root_mean_squared_error: 1.4290 - val_loss: 7.1087 - val_y1_output_loss: 1.1445 - val_y2_output_loss: 5.9641 - val_y1_output_root_mean_squared_error: 1.0698 - val_y2_output_root_mean_squared_error: 2.4422
# Epoch 111/500
# 62/62 [==============================] - 1s 10ms/step - loss: 2.9493 - y1_output_loss: 0.6351 - y2_output_loss: 2.3143 - y1_output_root_mean_squared_error: 0.7969 - y2_output_root_mean_squared_error: 1.5213 - val_loss: 4.7640 - val_y1_output_loss: 1.0999 - val_y2_output_loss: 3.6641 - val_y1_output_root_mean_squared_error: 1.0488 - val_y2_output_root_mean_squared_error: 1.9142
# Epoch 112/500
# 62/62 [==============================] - 1s 10ms/step - loss: 2.6138 - y1_output_loss: 0.5998 - y2_output_loss: 2.0140 - y1_output_root_mean_squared_error: 0.7745 - y2_output_root_mean_squared_error: 1.4192 - val_loss: 21.2264 - val_y1_output_loss: 7.5157 - val_y2_output_loss: 13.7107 - val_y1_output_root_mean_squared_error: 2.7415 - val_y2_output_root_mean_squared_error: 3.7028
# Epoch 113/500
# 62/62 [==============================] - 1s 9ms/step - loss: 4.3213 - y1_output_loss: 0.9331 - y2_output_loss: 3.3882 - y1_output_root_mean_squared_error: 0.9660 - y2_output_root_mean_squared_error: 1.8407 - val_loss: 2.8970 - val_y1_output_loss: 0.5976 - val_y2_output_loss: 2.2994 - val_y1_output_root_mean_squared_error: 0.7730 - val_y2_output_root_mean_squared_error: 1.5164
# Epoch 114/500
# 62/62 [==============================] - 1s 12ms/step - loss: 2.6514 - y1_output_loss: 0.5989 - y2_output_loss: 2.0525 - y1_output_root_mean_squared_error: 0.7739 - y2_output_root_mean_squared_error: 1.4327 - val_loss: 2.3192 - val_y1_output_loss: 0.3927 - val_y2_output_loss: 1.9265 - val_y1_output_root_mean_squared_error: 0.6266 - val_y2_output_root_mean_squared_error: 1.3880
# Epoch 115/500
# 62/62 [==============================] - 1s 24ms/step - loss: 2.2741 - y1_output_loss: 0.4837 - y2_output_loss: 1.7903 - y1_output_root_mean_squared_error: 0.6955 - y2_output_root_mean_squared_error: 1.3380 - val_loss: 3.7100 - val_y1_output_loss: 0.8524 - val_y2_output_loss: 2.8576 - val_y1_output_root_mean_squared_error: 0.9233 - val_y2_output_root_mean_squared_error: 1.6904
# Epoch 116/500
# 62/62 [==============================] - 1s 11ms/step - loss: 2.6868 - y1_output_loss: 0.5430 - y2_output_loss: 2.1438 - y1_output_root_mean_squared_error: 0.7369 - y2_output_root_mean_squared_error: 1.4642 - val_loss: 6.1643 - val_y1_output_loss: 1.7772 - val_y2_output_loss: 4.3872 - val_y1_output_root_mean_squared_error: 1.3331 - val_y2_output_root_mean_squared_error: 2.0946
# Epoch 117/500
# 62/62 [==============================] - 1s 13ms/step - loss: 4.1759 - y1_output_loss: 1.0541 - y2_output_loss: 3.1218 - y1_output_root_mean_squared_error: 1.0267 - y2_output_root_mean_squared_error: 1.7669 - val_loss: 6.9999 - val_y1_output_loss: 2.0120 - val_y2_output_loss: 4.9879 - val_y1_output_root_mean_squared_error: 1.4184 - val_y2_output_root_mean_squared_error: 2.2334
# Epoch 118/500
# 62/62 [==============================] - 1s 17ms/step - loss: 2.6782 - y1_output_loss: 0.6060 - y2_output_loss: 2.0722 - y1_output_root_mean_squared_error: 0.7785 - y2_output_root_mean_squared_error: 1.4395 - val_loss: 2.6977 - val_y1_output_loss: 0.5041 - val_y2_output_loss: 2.1935 - val_y1_output_root_mean_squared_error: 0.7100 - val_y2_output_root_mean_squared_error: 1.4811
# Epoch 119/500
# 62/62 [==============================] - 1s 10ms/step - loss: 3.7736 - y1_output_loss: 1.0772 - y2_output_loss: 2.6964 - y1_output_root_mean_squared_error: 1.0379 - y2_output_root_mean_squared_error: 1.6421 - val_loss: 2.5118 - val_y1_output_loss: 0.5241 - val_y2_output_loss: 1.9877 - val_y1_output_root_mean_squared_error: 0.7239 - val_y2_output_root_mean_squared_error: 1.4099
# Epoch 120/500
# ...
# Epoch 461/500
# 62/62 [==============================] - 1s 9ms/step - loss: 0.4233 - y1_output_loss: 0.1322 - y2_output_loss: 0.2911 - y1_output_root_mean_squared_error: 0.3636 - y2_output_root_mean_squared_error: 0.5395 - val_loss: 3.0281 - val_y1_output_loss: 0.7676 - val_y2_output_loss: 2.2605 - val_y1_output_root_mean_squared_error: 0.8761 - val_y2_output_root_mean_squared_error: 1.5035
# Epoch 462/500
# 62/62 [==============================] - 1s 10ms/step - loss: 0.4889 - y1_output_loss: 0.1268 - y2_output_loss: 0.3621 - y1_output_root_mean_squared_error: 0.3561 - y2_output_root_mean_squared_error: 0.6017 - val_loss: 1.2953 - val_y1_output_loss: 0.5440 - val_y2_output_loss: 0.7513 - val_y1_output_root_mean_squared_error: 0.7375 - val_y2_output_root_mean_squared_error: 0.8668
# Epoch 463/500
# 62/62 [==============================] - 1s 8ms/step - loss: 0.3758 - y1_output_loss: 0.1280 - y2_output_loss: 0.2478 - y1_output_root_mean_squared_error: 0.3578 - y2_output_root_mean_squared_error: 0.4978 - val_loss: 1.0550 - val_y1_output_loss: 0.2997 - val_y2_output_loss: 0.7553 - val_y1_output_root_mean_squared_error: 0.5475 - val_y2_output_root_mean_squared_error: 0.8691
# Epoch 464/500
# 62/62 [==============================] - 1s 9ms/step - loss: 0.6280 - y1_output_loss: 0.1677 - y2_output_loss: 0.4604 - y1_output_root_mean_squared_error: 0.4095 - y2_output_root_mean_squared_error: 0.6785 - val_loss: 1.3262 - val_y1_output_loss: 0.1993 - val_y2_output_loss: 1.1270 - val_y1_output_root_mean_squared_error: 0.4464 - val_y2_output_root_mean_squared_error: 1.0616
# Epoch 465/500
# 62/62 [==============================] - 0s 7ms/step - loss: 0.3747 - y1_output_loss: 0.1122 - y2_output_loss: 0.2624 - y1_output_root_mean_squared_error: 0.3350 - y2_output_root_mean_squared_error: 0.5123 - val_loss: 1.2860 - val_y1_output_loss: 0.2351 - val_y2_output_loss: 1.0509 - val_y1_output_root_mean_squared_error: 0.4849 - val_y2_output_root_mean_squared_error: 1.0251
# Epoch 466/500
# 62/62 [==============================] - 1s 9ms/step - loss: 0.8121 - y1_output_loss: 0.1820 - y2_output_loss: 0.6301 - y1_output_root_mean_squared_error: 0.4266 - y2_output_root_mean_squared_error: 0.7938 - val_loss: 0.9661 - val_y1_output_loss: 0.2861 - val_y2_output_loss: 0.6801 - val_y1_output_root_mean_squared_error: 0.5349 - val_y2_output_root_mean_squared_error: 0.8247
# Epoch 467/500
# 62/62 [==============================] - 0s 8ms/step - loss: 0.5096 - y1_output_loss: 0.1303 - y2_output_loss: 0.3792 - y1_output_root_mean_squared_error: 0.3610 - y2_output_root_mean_squared_error: 0.6158 - val_loss: 1.0178 - val_y1_output_loss: 0.3144 - val_y2_output_loss: 0.7034 - val_y1_output_root_mean_squared_error: 0.5607 - val_y2_output_root_mean_squared_error: 0.8387
# Epoch 468/500
# 62/62 [==============================] - 0s 8ms/step - loss: 0.3524 - y1_output_loss: 0.1148 - y2_output_loss: 0.2376 - y1_output_root_mean_squared_error: 0.3388 - y2_output_root_mean_squared_error: 0.4875 - val_loss: 0.8620 - val_y1_output_loss: 0.1957 - val_y2_output_loss: 0.6663 - val_y1_output_root_mean_squared_error: 0.4424 - val_y2_output_root_mean_squared_error: 0.8163
# Epoch 469/500
# 62/62 [==============================] - 0s 7ms/step - loss: 0.6823 - y1_output_loss: 0.1626 - y2_output_loss: 0.5197 - y1_output_root_mean_squared_error: 0.4032 - y2_output_root_mean_squared_error: 0.7209 - val_loss: 0.9227 - val_y1_output_loss: 0.2424 - val_y2_output_loss: 0.6804 - val_y1_output_root_mean_squared_error: 0.4923 - val_y2_output_root_mean_squared_error: 0.8249
# Epoch 470/500
# 62/62 [==============================] - 1s 8ms/step - loss: 0.3949 - y1_output_loss: 0.1114 - y2_output_loss: 0.2835 - y1_output_root_mean_squared_error: 0.3338 - y2_output_root_mean_squared_error: 0.5324 - val_loss: 1.5407 - val_y1_output_loss: 0.3919 - val_y2_output_loss: 1.1488 - val_y1_output_root_mean_squared_error: 0.6260 - val_y2_output_root_mean_squared_error: 1.0718
# Epoch 471/500
# 62/62 [==============================] - 1s 8ms/step - loss: 0.7731 - y1_output_loss: 0.2116 - y2_output_loss: 0.5614 - y1_output_root_mean_squared_error: 0.4600 - y2_output_root_mean_squared_error: 0.7493 - val_loss: 1.7498 - val_y1_output_loss: 0.3634 - val_y2_output_loss: 1.3863 - val_y1_output_root_mean_squared_error: 0.6029 - val_y2_output_root_mean_squared_error: 1.1774
# Epoch 472/500
# 62/62 [==============================] - 1s 11ms/step - loss: 0.4566 - y1_output_loss: 0.1207 - y2_output_loss: 0.3359 - y1_output_root_mean_squared_error: 0.3475 - y2_output_root_mean_squared_error: 0.5795 - val_loss: 0.9517 - val_y1_output_loss: 0.2763 - val_y2_output_loss: 0.6754 - val_y1_output_root_mean_squared_error: 0.5256 - val_y2_output_root_mean_squared_error: 0.8218
# Epoch 473/500
# 62/62 [==============================] - 1s 9ms/step - loss: 0.3616 - y1_output_loss: 0.1107 - y2_output_loss: 0.2510 - y1_output_root_mean_squared_error: 0.3326 - y2_output_root_mean_squared_error: 0.5010 - val_loss: 0.7879 - val_y1_output_loss: 0.2213 - val_y2_output_loss: 0.5666 - val_y1_output_root_mean_squared_error: 0.4704 - val_y2_output_root_mean_squared_error: 0.7528
# Epoch 474/500
# 62/62 [==============================] - 1s 9ms/step - loss: 0.5688 - y1_output_loss: 0.1488 - y2_output_loss: 0.4200 - y1_output_root_mean_squared_error: 0.3858 - y2_output_root_mean_squared_error: 0.6480 - val_loss: 0.8010 - val_y1_output_loss: 0.2498 - val_y2_output_loss: 0.5511 - val_y1_output_root_mean_squared_error: 0.4998 - val_y2_output_root_mean_squared_error: 0.7424
# Epoch 475/500
# 62/62 [==============================] - 1s 12ms/step - loss: 0.3860 - y1_output_loss: 0.1095 - y2_output_loss: 0.2765 - y1_output_root_mean_squared_error: 0.3309 - y2_output_root_mean_squared_error: 0.5258 - val_loss: 0.9404 - val_y1_output_loss: 0.2545 - val_y2_output_loss: 0.6859 - val_y1_output_root_mean_squared_error: 0.5045 - val_y2_output_root_mean_squared_error: 0.8282
# Epoch 476/500
# 62/62 [==============================] - 0s 7ms/step - loss: 0.5797 - y1_output_loss: 0.1454 - y2_output_loss: 0.4343 - y1_output_root_mean_squared_error: 0.3813 - y2_output_root_mean_squared_error: 0.6590 - val_loss: 0.7734 - val_y1_output_loss: 0.2060 - val_y2_output_loss: 0.5674 - val_y1_output_root_mean_squared_error: 0.4539 - val_y2_output_root_mean_squared_error: 0.7532
# Epoch 477/500
# 62/62 [==============================] - 1s 9ms/step - loss: 0.3644 - y1_output_loss: 0.1164 - y2_output_loss: 0.2481 - y1_output_root_mean_squared_error: 0.3411 - y2_output_root_mean_squared_error: 0.4981 - val_loss: 1.0024 - val_y1_output_loss: 0.2641 - val_y2_output_loss: 0.7383 - val_y1_output_root_mean_squared_error: 0.5139 - val_y2_output_root_mean_squared_error: 0.8593
# Epoch 478/500
# 62/62 [==============================] - 1s 10ms/step - loss: 0.4069 - y1_output_loss: 0.1219 - y2_output_loss: 0.2850 - y1_output_root_mean_squared_error: 0.3492 - y2_output_root_mean_squared_error: 0.5339 - val_loss: 1.4154 - val_y1_output_loss: 0.3196 - val_y2_output_loss: 1.0958 - val_y1_output_root_mean_squared_error: 0.5653 - val_y2_output_root_mean_squared_error: 1.0468
# Epoch 479/500
# 62/62 [==============================] - 1s 8ms/step - loss: 0.4065 - y1_output_loss: 0.1187 - y2_output_loss: 0.2878 - y1_output_root_mean_squared_error: 0.3445 - y2_output_root_mean_squared_error: 0.5365 - val_loss: 1.1106 - val_y1_output_loss: 0.2937 - val_y2_output_loss: 0.8169 - val_y1_output_root_mean_squared_error: 0.5419 - val_y2_output_root_mean_squared_error: 0.9038
# Epoch 480/500
# 62/62 [==============================] - 0s 8ms/step - loss: 0.4398 - y1_output_loss: 0.1296 - y2_output_loss: 0.3102 - y1_output_root_mean_squared_error: 0.3599 - y2_output_root_mean_squared_error: 0.5570 - val_loss: 0.7974 - val_y1_output_loss: 0.2401 - val_y2_output_loss: 0.5574 - val_y1_output_root_mean_squared_error: 0.4900 - val_y2_output_root_mean_squared_error: 0.7466
# Epoch 481/500
# 62/62 [==============================] - 1s 11ms/step - loss: 0.3811 - y1_output_loss: 0.1197 - y2_output_loss: 0.2614 - y1_output_root_mean_squared_error: 0.3460 - y2_output_root_mean_squared_error: 0.5112 - val_loss: 0.9397 - val_y1_output_loss: 0.2776 - val_y2_output_loss: 0.6621 - val_y1_output_root_mean_squared_error: 0.5269 - val_y2_output_root_mean_squared_error: 0.8137
# Epoch 482/500
# 62/62 [==============================] - 1s 10ms/step - loss: 0.4311 - y1_output_loss: 0.1191 - y2_output_loss: 0.3120 - y1_output_root_mean_squared_error: 0.3451 - y2_output_root_mean_squared_error: 0.5586 - val_loss: 0.8179 - val_y1_output_loss: 0.2008 - val_y2_output_loss: 0.6170 - val_y1_output_root_mean_squared_error: 0.4482 - val_y2_output_root_mean_squared_error: 0.7855
# Epoch 483/500
# 62/62 [==============================] - 1s 11ms/step - loss: 0.4002 - y1_output_loss: 0.1111 - y2_output_loss: 0.2891 - y1_output_root_mean_squared_error: 0.3333 - y2_output_root_mean_squared_error: 0.5377 - val_loss: 0.9227 - val_y1_output_loss: 0.2109 - val_y2_output_loss: 0.7118 - val_y1_output_root_mean_squared_error: 0.4593 - val_y2_output_root_mean_squared_error: 0.8437
# Epoch 484/500
# 62/62 [==============================] - 1s 10ms/step - loss: 0.4283 - y1_output_loss: 0.1156 - y2_output_loss: 0.3127 - y1_output_root_mean_squared_error: 0.3400 - y2_output_root_mean_squared_error: 0.5592 - val_loss: 0.9540 - val_y1_output_loss: 0.3643 - val_y2_output_loss: 0.5898 - val_y1_output_root_mean_squared_error: 0.6035 - val_y2_output_root_mean_squared_error: 0.7680
# Epoch 485/500
# 62/62 [==============================] - 1s 9ms/step - loss: 0.4343 - y1_output_loss: 0.1280 - y2_output_loss: 0.3063 - y1_output_root_mean_squared_error: 0.3577 - y2_output_root_mean_squared_error: 0.5535 - val_loss: 0.9445 - val_y1_output_loss: 0.2460 - val_y2_output_loss: 0.6985 - val_y1_output_root_mean_squared_error: 0.4960 - val_y2_output_root_mean_squared_error: 0.8357
# Epoch 486/500
# 62/62 [==============================] - 1s 10ms/step - loss: 0.3515 - y1_output_loss: 0.1108 - y2_output_loss: 0.2407 - y1_output_root_mean_squared_error: 0.3329 - y2_output_root_mean_squared_error: 0.4906 - val_loss: 0.9493 - val_y1_output_loss: 0.2511 - val_y2_output_loss: 0.6982 - val_y1_output_root_mean_squared_error: 0.5011 - val_y2_output_root_mean_squared_error: 0.8356
# Epoch 487/500
# 62/62 [==============================] - 1s 9ms/step - loss: 0.4682 - y1_output_loss: 0.1220 - y2_output_loss: 0.3462 - y1_output_root_mean_squared_error: 0.3493 - y2_output_root_mean_squared_error: 0.5884 - val_loss: 1.2010 - val_y1_output_loss: 0.4968 - val_y2_output_loss: 0.7042 - val_y1_output_root_mean_squared_error: 0.7048 - val_y2_output_root_mean_squared_error: 0.8392
# Epoch 488/500
# 62/62 [==============================] - 1s 9ms/step - loss: 0.4113 - y1_output_loss: 0.1171 - y2_output_loss: 0.2942 - y1_output_root_mean_squared_error: 0.3422 - y2_output_root_mean_squared_error: 0.5424 - val_loss: 0.8730 - val_y1_output_loss: 0.2286 - val_y2_output_loss: 0.6444 - val_y1_output_root_mean_squared_error: 0.4782 - val_y2_output_root_mean_squared_error: 0.8027
# Epoch 489/500
# 62/62 [==============================] - 1s 9ms/step - loss: 0.3732 - y1_output_loss: 0.1109 - y2_output_loss: 0.2623 - y1_output_root_mean_squared_error: 0.3331 - y2_output_root_mean_squared_error: 0.5121 - val_loss: 1.2359 - val_y1_output_loss: 0.3847 - val_y2_output_loss: 0.8513 - val_y1_output_root_mean_squared_error: 0.6202 - val_y2_output_root_mean_squared_error: 0.9226
# Epoch 490/500
# 62/62 [==============================] - 1s 16ms/step - loss: 0.5738 - y1_output_loss: 0.1442 - y2_output_loss: 0.4296 - y1_output_root_mean_squared_error: 0.3797 - y2_output_root_mean_squared_error: 0.6555 - val_loss: 1.1404 - val_y1_output_loss: 0.2909 - val_y2_output_loss: 0.8495 - val_y1_output_root_mean_squared_error: 0.5394 - val_y2_output_root_mean_squared_error: 0.9217
# Epoch 491/500
# 62/62 [==============================] - 1s 13ms/step - loss: 0.4866 - y1_output_loss: 0.1349 - y2_output_loss: 0.3517 - y1_output_root_mean_squared_error: 0.3673 - y2_output_root_mean_squared_error: 0.5931 - val_loss: 0.8336 - val_y1_output_loss: 0.2065 - val_y2_output_loss: 0.6271 - val_y1_output_root_mean_squared_error: 0.4544 - val_y2_output_root_mean_squared_error: 0.7919
# Epoch 492/500
# 62/62 [==============================] - 1s 12ms/step - loss: 0.5245 - y1_output_loss: 0.1646 - y2_output_loss: 0.3599 - y1_output_root_mean_squared_error: 0.4058 - y2_output_root_mean_squared_error: 0.5999 - val_loss: 0.7853 - val_y1_output_loss: 0.2178 - val_y2_output_loss: 0.5675 - val_y1_output_root_mean_squared_error: 0.4667 - val_y2_output_root_mean_squared_error: 0.7533
# Epoch 493/500
# 62/62 [==============================] - 1s 9ms/step - loss: 0.3684 - y1_output_loss: 0.1136 - y2_output_loss: 0.2548 - y1_output_root_mean_squared_error: 0.3371 - y2_output_root_mean_squared_error: 0.5047 - val_loss: 0.8508 - val_y1_output_loss: 0.2026 - val_y2_output_loss: 0.6482 - val_y1_output_root_mean_squared_error: 0.4501 - val_y2_output_root_mean_squared_error: 0.8051
# Epoch 494/500
# 62/62 [==============================] - 1s 18ms/step - loss: 0.4306 - y1_output_loss: 0.1218 - y2_output_loss: 0.3088 - y1_output_root_mean_squared_error: 0.3490 - y2_output_root_mean_squared_error: 0.5557 - val_loss: 0.9478 - val_y1_output_loss: 0.2214 - val_y2_output_loss: 0.7264 - val_y1_output_root_mean_squared_error: 0.4705 - val_y2_output_root_mean_squared_error: 0.8523
# Epoch 495/500
# 62/62 [==============================] - 1s 10ms/step - loss: 0.3863 - y1_output_loss: 0.1187 - y2_output_loss: 0.2676 - y1_output_root_mean_squared_error: 0.3446 - y2_output_root_mean_squared_error: 0.5173 - val_loss: 0.9322 - val_y1_output_loss: 0.2233 - val_y2_output_loss: 0.7089 - val_y1_output_root_mean_squared_error: 0.4725 - val_y2_output_root_mean_squared_error: 0.8420
# Epoch 496/500
# 62/62 [==============================] - 1s 8ms/step - loss: 0.3443 - y1_output_loss: 0.1159 - y2_output_loss: 0.2284 - y1_output_root_mean_squared_error: 0.3404 - y2_output_root_mean_squared_error: 0.4779 - val_loss: 0.9932 - val_y1_output_loss: 0.2643 - val_y2_output_loss: 0.7289 - val_y1_output_root_mean_squared_error: 0.5141 - val_y2_output_root_mean_squared_error: 0.8537
# Epoch 497/500
# 62/62 [==============================] - 1s 12ms/step - loss: 0.2786 - y1_output_loss: 0.0967 - y2_output_loss: 0.1820 - y1_output_root_mean_squared_error: 0.3110 - y2_output_root_mean_squared_error: 0.4266 - val_loss: 0.9551 - val_y1_output_loss: 0.2563 - val_y2_output_loss: 0.6987 - val_y1_output_root_mean_squared_error: 0.5063 - val_y2_output_root_mean_squared_error: 0.8359
# Epoch 498/500
# 62/62 [==============================] - 1s 9ms/step - loss: 0.3188 - y1_output_loss: 0.1042 - y2_output_loss: 0.2145 - y1_output_root_mean_squared_error: 0.3229 - y2_output_root_mean_squared_error: 0.4632 - val_loss: 2.4497 - val_y1_output_loss: 0.4880 - val_y2_output_loss: 1.9618 - val_y1_output_root_mean_squared_error: 0.6985 - val_y2_output_root_mean_squared_error: 1.4006
# Epoch 499/500
# 62/62 [==============================] - 1s 15ms/step - loss: 0.5094 - y1_output_loss: 0.1374 - y2_output_loss: 0.3720 - y1_output_root_mean_squared_error: 0.3706 - y2_output_root_mean_squared_error: 0.6099 - val_loss: 1.3208 - val_y1_output_loss: 0.5057 - val_y2_output_loss: 0.8151 - val_y1_output_root_mean_squared_error: 0.7111 - val_y2_output_root_mean_squared_error: 0.9028
# Epoch 500/500
# 62/62 [==============================] - 1s 11ms/step - loss: 0.3672 - y1_output_loss: 0.1133 - y2_output_loss: 0.2540 - y1_output_root_mean_squared_error: 0.3366 - y2_output_root_mean_squared_error: 0.5039 - val_loss: 0.8567 - val_y1_output_loss: 0.2180 - val_y2_output_loss: 0.6387 - val_y1_output_root_mean_squared_error: 0.4669 - val_y2_output_root_mean_squared_error: 0.7992

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 32us/sample - loss: 1.0032 - y1_output_loss: 0.2707 - y2_output_loss: 0.7481 - y1_output_root_mean_squared_error: 0.5229 - y2_output_root_mean_squared_error: 0.8543
# Loss = 1.003245367632284, Y1_loss = 0.27068519592285156, Y1_mse = 0.5229426622390747, Y2_loss = 0.7481483221054077, Y2_mse = 0.8542695045471191

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
