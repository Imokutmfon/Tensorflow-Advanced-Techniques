# %% [markdown]
# # Week 2 Assignment: CIFAR-10 Autoencoder
#
# For this week, you will create a convolutional autoencoder for the [CIFAR10](https://www.tensorflow.org/datasets/catalog/cifar10) dataset. You are free to choose the architecture of your autoencoder provided that the output image has the same dimensions as the input image.
#
# After training, your model should meet loss and accuracy requirements when evaluated with the test dataset. You will then download the model and upload it in the classroom for grading.
#
# Let's begin!

# %% [markdown]
# ***Important:*** *This colab notebook has read-only access so you won't be able to save your changes. If you want to save your work periodically, please click `File -> Save a Copy in Drive` to create a copy in your account, then work from there.*

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
import tensorflow_datasets as tfds

from keras.models import Sequential
# Out:
# 2025-10-05 02:03:10.164235: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759629790.347339      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759629790.407303      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# ## Load and prepare the dataset
#
# The [CIFAR 10](https://www.tensorflow.org/datasets/catalog/cifar10) dataset already has train and test splits and you can use those in this exercise. Here are the general steps:
#
# * Load the train/test split from TFDS. Set `as_supervised` to `True` so it will be convenient to use the preprocessing function we provided.
# * Normalize the pixel values to the range [0,1], then return `image, image` pairs for training instead of `image, label`. This is because you will check if the output image is successfully regenerated after going through your autoencoder.
# * Shuffle and batch the train set. Batch the test set (no need to shuffle).

# %%
# preprocessing function
def map_image(image, label):
  image = tf.cast(image, dtype=tf.float32)
  image = image / 255.0

  return image, image # dataset label is not used. replaced with the same image input.

# parameters
BATCH_SIZE = 128
SHUFFLE_BUFFER_SIZE = 1024


### START CODE HERE (Replace instances of `None` with your code) ###

# use tfds.load() to fetch the 'train' split of CIFAR-10
train_dataset = tfds.load('cifar10', as_supervised=True, split='train').repeat(32)

# preprocess the dataset with the `map_image()` function above
train_dataset = train_dataset.map(map_image)

# shuffle and batch the dataset
train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)


# use tfds.load() to fetch the 'test' split of CIFAR-10
test_dataset = tfds.load('cifar10', as_supervised=True, split='test').repeat(32)

# preprocess the dataset with the `map_image()` function above
test_dataset = test_dataset.map(map_image)

# batch the dataset
test_dataset = test_dataset.batch(BATCH_SIZE)

### END CODE HERE ###
# Out:
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/cifar10/3.0.2...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# I0000 00:00:1759629810.550782      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1759629810.551437      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Shuffling /root/tensorflow_datasets/cifar10/incomplete.F1JKAM_3.0.2/cifar10-train.tfrecord*...:   0%|         …
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/cifar10/incomplete.F1JKAM_3.0.2/cifar10-test.tfrecord*...:   0%|          …
# Dataset cifar10 downloaded and prepared to /root/tensorflow_datasets/cifar10/3.0.2. Subsequent calls will reuse this data.

# %% [markdown]
# ## Build the Model
#
# Create the autoencoder model. As shown in the lectures, you will want to downsample the image in the encoder layers then upsample it in the decoder path. Note that the output layer should be the same dimensions as the original image. Your input images will have the shape `(32, 32, 3)`. If you deviate from this, your model may not be recognized by the grader and may fail.
#
# We included a few hints to use the Sequential API below but feel free to remove it and use the Functional API just like in the ungraded labs if you're more comfortable with it. Another reason to use the latter is if you want to visualize the encoder output. As shown in the ungraded labs, it will be easier to indicate multiple outputs with the Functional API. That is not required for this assignment though so you can just stack layers sequentially if you want a simpler solution.

# %%
# suggested layers to use. feel free to add or remove as you see fit.
from keras.layers import Conv2D, UpSampling2D, BatchNormalization, MaxPooling2D, Dropout

# use the Sequential API (you can remove if you want to use the Functional API)
model = Sequential()

### START CODE HERE ###
# use `model.add()` to add layers to your autoencoder (if using the Sequential API)
model.add(tf.keras.Input(shape=(32,32,3)))
model.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))

# define bottleneck
model.add(Conv2D(filters=512, kernel_size=(3,3), activation='relu', padding='same'))
model.add(Dropout(0.2))

# define decoder
model.add(Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(UpSampling2D(size=(2,2)))
model.add(Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(UpSampling2D(size=(2,2)))
model.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(UpSampling2D(size=(2,2)))
model.add(Conv2D(filters=3, kernel_size=(3,3), activation='sigmoid', padding='same'))







### END CODE HERE ###

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 8, 8, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 8, 8, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 4, 4, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 4, 4, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 4, 4, 256)      │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 4, 4, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d (UpSampling2D)    │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 128)      │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_1 (UpSampling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 16, 16, 64)     │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_2 (UpSampling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 32, 32, 3)      │         1,731 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,105,027 (11.84 MB)
#  Trainable params: 3,103,235 (11.84 MB)
#  Non-trainable params: 1,792 (7.00 KB)

# %% [markdown]
# ## Configure training parameters
#
# We have already provided the optimizer, metrics, and loss in the code below.

# %%
# Please do not change the model.compile() parameters
model.compile(optimizer='adam', metrics=['accuracy'], loss='mean_squared_error')

# %%
# !pip install visualkeras
import visualkeras

visualkeras.layered_view(
    model,
    legend=True,
    draw_volume=True,
    to_file='autoencoder_model.png'
)
# Out:
# Collecting visualkeras
#   Downloading visualkeras-0.1.4-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from visualkeras) (11.2.1)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.11/dist-packages (from visualkeras) (1.26.4)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.19-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (655 bytes)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->visualkeras) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->visualkeras) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->visualkeras) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->visualkeras) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->visualkeras) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->visualkeras) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.18.1->visualkeras) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.18.1->visualkeras) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.18.1->visualkeras) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.18.1->visualkeras) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.18.1->visualkeras) (2024.2.0)
# Downloading visualkeras-0.1.4-py3-none-any.whl (17 kB)
# Downloading aggdraw-1.3.19-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (997 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 997.4/997.4 kB 14.2 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.19 visualkeras-0.1.4
# /usr/local/lib/python3.11/dist-packages/visualkeras/layered.py:86: UserWarning: The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.
#   warnings.warn("The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.")
# <PIL.Image.Image image mode=RGBA size=779x209>

# %% [markdown]
# ## Training
#
# You can now use [model.fit()](https://keras.io/api/models/model_training_apis/#fit-method) to train your model. You will pass in the `train_dataset` and you are free to configure the other parameters. As with any training, you should observe the loss generally going down and the accuracy going up at each epoch. If not, please revisit the previous sections to find possible bugs.
#
# *Note: If you get a `dataset length is infinite` error. Please check how you defined `train_dataset`. You might have included a [method that repeats the dataset indefinitely](https://www.tensorflow.org/api_docs/python/tf/data/Dataset#repeat).*

# %%
### START CODE HERE ###
train_steps = len(train_dataset) // BATCH_SIZE
valid_steps = len(test_dataset) // BATCH_SIZE

model.fit(train_dataset, steps_per_epoch=train_steps, validation_data=test_dataset, epochs=40)
### END CODE HERE ###
# Out:
# Epoch 1/40
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1759629884.840892      66 service.cc:148] XLA service 0x7e671c006ee0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1759629884.841758      66 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1759629884.841981      66 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1759629885.541755      66 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  3/97 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.3815 - loss: 0.1083
# I0000 00:00:1759629893.187173      66 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 43s 288ms/step - accuracy: 0.5201 - loss: 0.0315 - val_accuracy: 0.2221 - val_loss: 0.0608
# Epoch 2/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 26s 275ms/step - accuracy: 0.6756 - loss: 0.0122 - val_accuracy: 0.5531 - val_loss: 0.0420
# Epoch 3/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 291ms/step - accuracy: 0.7097 - loss: 0.0102 - val_accuracy: 0.6092 - val_loss: 0.0270
# Epoch 4/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 295ms/step - accuracy: 0.7204 - loss: 0.0088 - val_accuracy: 0.6723 - val_loss: 0.0165
# Epoch 5/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 27s 286ms/step - accuracy: 0.7319 - loss: 0.0076 - val_accuracy: 0.7262 - val_loss: 0.0092
# Epoch 6/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 286ms/step - accuracy: 0.7406 - loss: 0.0070 - val_accuracy: 0.7455 - val_loss: 0.0074
# Epoch 7/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 292ms/step - accuracy: 0.7466 - loss: 0.0066 - val_accuracy: 0.7620 - val_loss: 0.0061
# Epoch 8/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 289ms/step - accuracy: 0.7454 - loss: 0.0061 - val_accuracy: 0.7540 - val_loss: 0.0062
# Epoch 9/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 287ms/step - accuracy: 0.7487 - loss: 0.0058 - val_accuracy: 0.7436 - val_loss: 0.0058
# Epoch 10/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 288ms/step - accuracy: 0.7514 - loss: 0.0057 - val_accuracy: 0.7485 - val_loss: 0.0059
# Epoch 11/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 289ms/step - accuracy: 0.7571 - loss: 0.0056 - val_accuracy: 0.7505 - val_loss: 0.0060
# Epoch 12/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 289ms/step - accuracy: 0.7608 - loss: 0.0052 - val_accuracy: 0.7618 - val_loss: 0.0052
# Epoch 13/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 289ms/step - accuracy: 0.7650 - loss: 0.0052 - val_accuracy: 0.7849 - val_loss: 0.0051
# Epoch 14/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 289ms/step - accuracy: 0.7642 - loss: 0.0049 - val_accuracy: 0.7589 - val_loss: 0.0051
# Epoch 15/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 291ms/step - accuracy: 0.7674 - loss: 0.0048 - val_accuracy: 0.7842 - val_loss: 0.0049
# Epoch 16/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 290ms/step - accuracy: 0.7668 - loss: 0.0047 - val_accuracy: 0.7643 - val_loss: 0.0044
# Epoch 17/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 290ms/step - accuracy: 0.7727 - loss: 0.0046 - val_accuracy: 0.7838 - val_loss: 0.0043
# Epoch 18/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 291ms/step - accuracy: 0.7714 - loss: 0.0046 - val_accuracy: 0.7580 - val_loss: 0.0042
# Epoch 19/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 291ms/step - accuracy: 0.7760 - loss: 0.0045 - val_accuracy: 0.7636 - val_loss: 0.0041
# Epoch 20/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 291ms/step - accuracy: 0.7707 - loss: 0.0045 - val_accuracy: 0.7394 - val_loss: 0.0067
# Epoch 21/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 291ms/step - accuracy: 0.7739 - loss: 0.0046 - val_accuracy: 0.7795 - val_loss: 0.0047
# Epoch 22/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 291ms/step - accuracy: 0.7757 - loss: 0.0043 - val_accuracy: 0.7470 - val_loss: 0.0045
# Epoch 23/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 294ms/step - accuracy: 0.7694 - loss: 0.0047 - val_accuracy: 0.7887 - val_loss: 0.0040
# Epoch 24/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 292ms/step - accuracy: 0.7788 - loss: 0.0041 - val_accuracy: 0.7803 - val_loss: 0.0039
# Epoch 25/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 291ms/step - accuracy: 0.7791 - loss: 0.0042 - val_accuracy: 0.7943 - val_loss: 0.0042
# Epoch 26/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 292ms/step - accuracy: 0.7821 - loss: 0.0040 - val_accuracy: 0.8039 - val_loss: 0.0041
# Epoch 27/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 293ms/step - accuracy: 0.7846 - loss: 0.0040 - val_accuracy: 0.6965 - val_loss: 0.0141
# Epoch 28/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 292ms/step - accuracy: 0.7741 - loss: 0.0040 - val_accuracy: 0.7703 - val_loss: 0.0038
# Epoch 29/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 291ms/step - accuracy: 0.7796 - loss: 0.0039 - val_accuracy: 0.7707 - val_loss: 0.0038
# Epoch 30/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 290ms/step - accuracy: 0.7849 - loss: 0.0038 - val_accuracy: 0.7992 - val_loss: 0.0037
# Epoch 31/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 291ms/step - accuracy: 0.7888 - loss: 0.0037 - val_accuracy: 0.7761 - val_loss: 0.0042
# Epoch 32/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 291ms/step - accuracy: 0.7850 - loss: 0.0038 - val_accuracy: 0.7773 - val_loss: 0.0036
# Epoch 33/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 291ms/step - accuracy: 0.7878 - loss: 0.0037 - val_accuracy: 0.7763 - val_loss: 0.0035
# Epoch 34/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 290ms/step - accuracy: 0.7848 - loss: 0.0037 - val_accuracy: 0.7851 - val_loss: 0.0034
# Epoch 35/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 291ms/step - accuracy: 0.7906 - loss: 0.0036 - val_accuracy: 0.7838 - val_loss: 0.0033
# Epoch 36/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 290ms/step - accuracy: 0.7866 - loss: 0.0035 - val_accuracy: 0.7969 - val_loss: 0.0035
# Epoch 37/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 289ms/step - accuracy: 0.7894 - loss: 0.0036 - val_accuracy: 0.7679 - val_loss: 0.0039
# Epoch 38/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 291ms/step - accuracy: 0.7898 - loss: 0.0036 - val_accuracy: 0.8085 - val_loss: 0.0034
# Epoch 39/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 290ms/step - accuracy: 0.7927 - loss: 0.0036 - val_accuracy: 0.7657 - val_loss: 0.0039
# Epoch 40/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 28s 289ms/step - accuracy: 0.7923 - loss: 0.0035 - val_accuracy: 0.7952 - val_loss: 0.0032

# %% [markdown]
# ## Model evaluation
#
# You can use this code to test your model locally before uploading to the grader. To pass, your model needs to satisfy these two requirements:
#
# * loss must be less than 0.01
# * accuracy must be greater than 0.6

# %%
result = model.evaluate(test_dataset, steps=10)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7950 - loss: 0.0032

# %% [markdown]
# If you did some visualization like in the ungraded labs, then you might see something like the gallery below. This part is not required.

# %% [markdown]
# <img src="https://storage.googleapis.com/tensorflow-3-public/assets/images/autoencoder.png" width="75%" height="75%"/>

# %% [markdown]
# ## Save the Model
#
# Once you're satisfied with the results, you can save your model and upload it to the grader in Coursera. Please run all succeeding cells to ensure that you will have a gradable submission. Otherwise, you might get this error message:
#
# `There was a problem grading your submission. Check stderr for more details.`
#
# First, save the model file in your Colab workspace.

# %%
# Save the model you just trained
model.save("mymodel.keras")

# %%
# # You can also use this cell as a shortcut for downloading your model
# from google.colab import files
# files.download("mymodel.keras")

# %% [markdown]
# **Congratulations on completing this week's assignment!**
